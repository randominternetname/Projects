# %%
'''
Grouping into plays

Data source: https://www.kaggle.com/kingburrito666/shakespeare-plays

Note: S's plays contain English, Latin, French, and nonsense.'''

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity

# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv('Shakespeare_data.csv')

# %%
df.head()
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               NaN          NaN            NaN
# 1         2  Henry IV               NaN          NaN            NaN
# 2         3  Henry IV               NaN          NaN            NaN
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %%
df.drop(['Dataline'], axis=1, inplace=True)

# %%
# Extracting the Act and Scene for all plays
df['ActScene']=df['ActSceneLine'].str[:4]

# %%
df.shape
# Out:
# (111396, 6)

# %%
# df = df[~(df.PlayerLine.str.contains('ACT'))]
# df = df[~(df.PlayerLine.str.contains('SCENE'))]
df = df[~(df.PlayerLine.str.contains(r"[A-Z]{2,}"))]
df = df[~df.PlayerLine.str.contains('Enter')]
df = df[~df.PlayerLine.str.contains('Exit')]
df = df[~df.PlayerLine.str.contains('Exeunt')]
# TRY THIS!
#indices = df.index[df['column'].contains('ACT') or condition ...etc]
#df.drop(indices, axis = 0, inplace=True)

# %%
df.head()
# Out:
#        Play  PlayerLinenumber ActSceneLine         Player  \
# 3  Henry IV               1.0        1.1.1  KING HENRY IV
# 4  Henry IV               1.0        1.1.2  KING HENRY IV
# 5  Henry IV               1.0        1.1.3  KING HENRY IV
# 6  Henry IV               1.0        1.1.4  KING HENRY IV
# 7  Henry IV               1.0        1.1.5  KING HENRY IV
#
#                                        PlayerLine ActScene
# 3          So shaken as we are, so wan with care,     1.1.
# 4      Find we a time for frighted peace to pant,     1.1.
# 5  And breathe short-winded accents of new broils     1.1.
# 6         To be commenced in strands afar remote.     1.1.
# 7       No more the thirsty entrance of this soil     1.1.

# %%
df.shape
# Out:
# (105307, 6)

# %%
#group by Player then join lines into speeches
df_speeches = df.groupby(['Play','PlayerLinenumber','Player','ActScene'])['PlayerLine'].apply(lambda x: ','.join(x)).reset_index()

# %%
df_speeches
# Out:
#                      Play  PlayerLinenumber          Player ActScene  \
# 0      A Comedy of Errors               1.0         ADRIANA     2.1.
# 1      A Comedy of Errors               1.0         ADRIANA     4.2.
# 2      A Comedy of Errors               1.0          AEGEON     1.1.
# 3      A Comedy of Errors               1.0          ANGELO     5.1.
# 4      A Comedy of Errors               1.0  First Merchant     1.2.
# ...                   ...               ...             ...      ...
# 30034             macbeth              61.0         MALCOLM     4.3.
# 30035             macbeth              62.0         MACDUFF     4.3.
# 30036             macbeth              63.0         MALCOLM     4.3.
# 30037             macbeth              64.0         MACDUFF     4.3.
# 30038             macbeth              65.0         MALCOLM     4.3.
#
#                                               PlayerLine
# 0      Neither my husband nor the slave return'd,,Tha...
# 1      Ah, Luciana, did he tempt thee so?,Mightst tho...
# 2      Proceed, Solinus, to procure my fall,And by th...
# 3      I am sorry, sir, that I have hinder'd you,,But...
# 4      Therefore give out you are of Epidamnum,,Lest ...
# ...                                                  ...
# 30034                             Dispute it like a man.
# 30035  I shall do so,,But I must also feel it as a ma...
# 30036  Be this the whetstone of your sword: let grief...
# 30037  O, I could play the woman with mine eyes,And b...
# 30038  This tune goes manly.,Come, go we to the king,...
#
# [30039 rows x 5 columns]

# %%
#check that I got the full speeches
df_speeches.iloc[0,4]
# Out:
# "Neither my husband nor the slave return'd,,That in such haste I sent to seek his master!,Sure, Luciana, it is two o'clock."

# %%
#now the play is back in order

df_speeches2 = (df_speeches.sort_values(['Play','ActScene', 'PlayerLinenumber'], ascending=[True, True, True]))

# %%
df_speeches2
# Out:
#                      Play  PlayerLinenumber        Player ActScene  \
# 2      A Comedy of Errors               1.0        AEGEON     1.1.
# 16     A Comedy of Errors               2.0  DUKE SOLINUS     1.1.
# 24     A Comedy of Errors               3.0        AEGEON     1.1.
# 37     A Comedy of Errors               4.0  DUKE SOLINUS     1.1.
# 46     A Comedy of Errors               5.0        AEGEON     1.1.
# ...                   ...               ...           ...      ...
# 29791             macbeth              19.0       MALCOLM     5.8.
# 29804             macbeth              20.0        SIWARD     5.8.
# 29813             macbeth              21.0       MACDUFF     5.8.
# 29818             macbeth              22.0           ALL     5.8.
# 29835             macbeth              23.0       MALCOLM     5.8.
#
#                                               PlayerLine
# 2      Proceed, Solinus, to procure my fall,And by th...
# 16     Merchant of Syracuse, plead no more,,I am not ...
# 24     Yet this my comfort: when your words are done,...
# 37     Well, Syracusian, say in brief the cause,Why t...
# 46     A heavier task could not have been imposed,Tha...
# ...                                                  ...
# 29791  He's worth more sorrow,,And that I'll spend fo...
# 29804  He's worth no more,They say he parted well, an...
# 29813  Hail, king! for so thou art: behold, where sta...
# 29818                            Hail, King of Scotland!
# 29835  We shall not spend a large expense of time,Bef...
#
# [30039 rows x 5 columns]

# %%
#group by Play then join speeches into play documents
df_plays = df_speeches2.groupby(['Play'])['PlayerLine'].apply(lambda x: ','.join(x)).reset_index()

# %%
df_plays
# Out:
#                         Play  \
# 0         A Comedy of Errors
# 1   A Midsummer nights dream
# 2             A Winters Tale
# 3   Alls well that ends well
# 4       Antony and Cleopatra
# 5             As you like it
# 6                 Coriolanus
# 7                  Cymbeline
# 8                     Hamlet
# 9                   Henry IV
# 10                   Henry V
# 11           Henry VI Part 1
# 12           Henry VI Part 2
# 13           Henry VI Part 3
# 14                Henry VIII
# 15             Julius Caesar
# 16                 King John
# 17                 King Lear
# 18        Loves Labours Lost
# 19       Measure for measure
# 20        Merchant of Venice
# 21    Merry Wives of Windsor
# 22    Much Ado about nothing
# 23                   Othello
# 24                  Pericles
# 25                Richard II
# 26               Richard III
# 27          Romeo and Juliet
# 28       Taming of the Shrew
# 29               The Tempest
# 30           Timon of Athens
# 31          Titus Andronicus
# 32      Troilus and Cressida
# 33             Twelfth Night
# 34   Two Gentlemen of Verona
# 35                   macbeth
#
#                                            PlayerLine
# 0   Proceed, Solinus, to procure my fall,And by th...
# 1   Now, fair Hippolyta, our nuptial hour,Draws on...
# 2   If you shall chance, Camillo, to visit Bohemia...
# 3   In delivering my son from me, I bury a second ...
# 4   Nay, but this dotage of our general's,O'erflow...
# 5   As I remember, Adam, it was upon this fashion,...
# 6   Before we proceed any further, hear me speak.,...
# 7   You do not meet a man but frowns: our bloods,N...
# 8   Who's there?,Nay, answer me: stand, and unfold...
# 9   So shaken as we are, so wan with care,,Find we...
# 10  O for a Muse of fire, that would ascend,The br...
# 11  Hung be the heavens with black, yield day to n...
# 12  As by your high imperial majesty,I had in char...
# 13  I wonder how the king escaped our hands.,While...
# 14  I come no more to make you laugh: things now,,...
# 15  Hence! home, you idle creatures get you home:,...
# 16  Now, say, Chatillon, what would France with us...
# 17  I thought the king had more affected the Duke ...
# 18  Let fame, that all hunt after in their lives,,...
# 19  Escalus.,My lord.,Of government the properties...
# 20  In sooth, I know not why I am so sad:,It weari...
# 21  Sir Hugh, persuade me not, I will make a Star-...
# 22  I learn in this letter that Don Peter of Arrag...
# 23  Tush! never tell me, I take it much unkindly,T...
# 24  To sing a song that old was sung,,From ashes a...
# 25  Old John of Gaunt, time-honour'd Lancaster,,Ha...
# 26  Now is the winter of our discontent,Made glori...
# 27  Two households, both alike in dignity,,In fair...
# 28  I'll pheeze you, in faith.,A pair of stocks, y...
# 29  Boatswain!,Here, master: what cheer?,Good, spe...
# 30  Good day, sir.,I am glad you're well.,I have n...
# 31  Noble patricians, patrons of my right,,Defend ...
# 32  In Troy, there lies the scene. From isles of G...
# 33  If music be the food of love, play on,,Give me...
# 34  Cease to persuade, my loving Proteus:,Home-kee...
# 35  When shall we three meet again,In thunder, lig...

# %%
# Save a df of plays into a pickle file.
import pickle

pickle.dump( df_plays, open( "shake_plays.p", "wb" ) )

# %%
#List unique values in the df['name'] column
players = list(df.Player.unique())

# %%
players
# Out:
# ['KING HENRY IV',
#  'WESTMORELAND',
#  'FALSTAFF',
#  'PRINCE HENRY',
#  'POINS',
#  'EARL OF WORCESTER',
#  'NORTHUMBERLAND',
#  'HOTSPUR',
#  'SIR WALTER BLUNT',
#  'First Carrier',
#  'Ostler',
#  'Second Carrier',
#  'GADSHILL',
#  'Chamberlain',
#  'BARDOLPH',
#  'PETO',
#  'First Traveller',
#  'Thieves',
#  'Travellers',
#  'LADY PERCY',
#  'Servant',
#  'FRANCIS',
#  'Vintner',
#  'Hostess',
#  'Sheriff',
#  'Carrier',
#  'MORTIMER',
#  'GLENDOWER',
#  nan,
#  'EARL OF DOUGLAS',
#  'Messenger',
#  'VERNON',
#  'WORCESTER',
#  'ARCHBISHOP OF YORK',
#  'SIR MICHAEL',
#  'LANCASTER',
#  'BEDFORD',
#  'GLOUCESTER',
#  'EXETER',
#  'OF WINCHESTER',
#  'CHARLES',
#  'ALENCON',
#  'REIGNIER',
#  'BASTARD OF ORLEANS',
#  'JOAN LA PUCELLE',
#  'First Warder',
#  'Second Warder',
#  'WOODVILE',
#  'Mayor',
#  'Officer',
#  'Boy',
#  'SALISBURY',
#  'TALBOT',
#  'GARGRAVE',
#  'GLANSDALE',
#  'Sergeant',
#  'First Sentinel',
#  'BURGUNDY',
#  'Sentinels',
#  'Soldier',
#  'Captain',
#  'OF AUVERGNE',
#  'Porter',
#  'PLANTAGENET',
#  'SUFFOLK',
#  'SOMERSET',
#  'WARWICK',
#  'Lawyer',
#  'First Gaoler',
#  'KING HENRY VI',
#  'ALL',
#  'First Soldier',
#  'Watch',
#  'FASTOLFE',
#  'BASSET',
#  'YORK',
#  'General',
#  'LUCY',
#  'JOHN TALBOT',
#  'Legate',
#  'Scout',
#  'MARGARET',
#  'SU FFOLK',
#  'Shepherd',
#  'QUEEN MARGARET',
#  'CARDINAL',
#  'BUCKINGHAM',
#  'DUCHESS',
#  'HUME',
#  'First Petitioner',
#  'Second Petitioner',
#  'PETER',
#  'HORNER',
#  'BOLINGBROKE',
#  'Spirit',
#  'MARGARET JOURDAIN',
#  'Townsman',
#  'SIMPCOX',
#  'Wife',
#  'Beadle',
#  'BOTH',
#  'First Neighbour',
#  'Second Neighbour',
#  'Third Neighbour',
#  'Servants',
#  'Herald',
#  'STANLEY',
#  'Post',
#  'First Murderer',
#  'Second Murderer',
#  'First Murder',
#  'Commons',
#  'VAUX',
#  'First Gentleman',
#  'Master',
#  'Second Gentleman',
#  'WHITMORE',
#  'BEVIS',
#  'HOLLAND',
#  'CADE',
#  'DICK',
#  'SMITH',
#  'Clerk',
#  'CLERK',
#  'MICHAEL',
#  'SIR HUMPHREY',
#  'WILLIAM STAFFORD',
#  'SAY',
#  'SCALES',
#  'First Citizen',
#  'CLIFFORD',
#  'IDEN',
#  'EDWARD',
#  'RICHARD',
#  'YOUNG CLIFFORD',
#  'MONTAGUE',
#  'NORFOLK',
#  'PRINCE EDWARD',
#  'JOHN MORTIMER',
#  'RUTLAND',
#  'Tutor',
#  'PRINCE',
#  'GEORGE',
#  'Son',
#  'Father',
#  'First Keeper',
#  'Second Keeper',
#  'KING EDWARD IV',
#  'CLARENCE',
#  'LADY GREY',
#  'Nobleman',
#  'KING LEWIS XI',
#  'OXFORD',
#  'BONA',
#  'HASTINGS',
#  'QUEEN ELIZABETH',
#  'First Watchman',
#  'Second Watchman',
#  'Third Watchman',
#  'RIVERS',
#  'Huntsman',
#  'Lieutenant',
#  'All',
#  'First Messenger',
#  'Second Messenger',
#  'COUNTESS',
#  'BERTRAM',
#  'LAFEU',
#  'HELENA',
#  'PAROLLES',
#  'Page',
#  'KING',
#  'First Lord',
#  'Second Lord',
#  'Steward',
#  'Clown',
#  'Both',
#  'Fourth Lord',
#  'DUKE',
#  'Widow',
#  'DIANA',
#  'MARIANA',
#  'Second Soldier',
#  'Gentleman',
#  'ORLANDO',
#  'ADAM',
#  'OLIVER',
#  'DENNIS',
#  'CELIA',
#  'ROSALIND',
#  'TOUCHSTONE',
#  'LE BEAU',
#  'DUKE FREDERICK',
#  'DUKE SENIOR',
#  'AMIENS',
#  'CORIN',
#  'SILVIUS',
#  'JAQUES',
#  'AUDREY',
#  'SIR OLIVER MARTEXT',
#  'PHEBE',
#  'A Lord',
#  'Forester',
#  'WILLIAM',
#  'First Page',
#  'Second Page',
#  'HYMEN',
#  'JAQUES DE BOYS',
#  'PHILO',
#  'CLEOPATRA',
#  'MARK ANTONY',
#  'Attendant',
#  'DEMETRIUS',
#  'CHARMIAN',
#  'ALEXAS',
#  'Soothsayer',
#  'DOMITIUS ENOBARBUS',
#  'IRAS',
#  'First Attendant',
#  'Second Attendant',
#  'OCTAVIUS CAESAR',
#  'LEPIDUS',
#  'MARDIAN',
#  'POMPEY',
#  'MENECRATES',
#  'MENAS',
#  'VARRIUS',
#  'MECAENAS',
#  'AGRIPPA',
#  'OCTAVIA',
#  'Attendants',
#  'First Servant',
#  'Second Servant',
#  'VENTIDIUS',
#  'SILIUS',
#  'EROS',
#  'CANIDIUS',
#  'TAURUS',
#  'SCARUS',
#  'DOLABELLA',
#  'EUPHRONIUS',
#  'THYREUS',
#  'Third Soldier',
#  'Fourth Soldier',
#  'First Guard',
#  'Second Guard',
#  'Third Guard',
#  'DERCETAS',
#  'DIOMEDES',
#  'Egyptian',
#  'PROCULEIUS',
#  'GALLUS',
#  'SELEUCUS',
#  'Guard',
#  'AEGEON',
#  'DUKE SOLINUS',
#  'Gaoler',
#  'First Merchant',
#  'OF SYRACUSE',
#  'DROMIO OF SYRACUSE',
#  'DROMIO OF EPHESUS',
#  'ADRIANA',
#  'LUCIANA',
#  'OF EPHESUS',
#  'BALTHAZAR',
#  'LUCE',
#  'ANTIPHOLUS',
#  'ANGELO',
#  'Second Merchant',
#  'Courtezan',
#  'PINCH',
#  'AEMELIA',
#  'Second Citizen',
#  'MENENIUS',
#  'MARCIUS',
#  'First Senator',
#  'COMINIUS',
#  'TITUS',
#  'SICINIUS',
#  'BRUTUS',
#  'AUFIDIUS',
#  'Second Senator',
#  'VOLUMNIA',
#  'VIRGILIA',
#  'Gentlewoman',
#  'VALERIA',
#  'LARTIUS',
#  'First Roman',
#  'Second Roman',
#  'Third Roman',
#  'CORIOLANUS',
#  'First Officer',
#  'Second Officer',
#  'Senators',
#  'Third Citizen',
#  'Fourth Citizen',
#  'Fifth Citizen',
#  'Both Citizens',
#  'Sixth Citizen',
#  'Seventh Citizen',
#  'All Citizens',
#  'Citizens',
#  'AEdile',
#  'A Patrician',
#  'Second Patrician',
#  'Both Tribunes',
#  'Roman',
#  'Volsce',
#  'Citizen',
#  'First Servingman',
#  'Second Servingman',
#  'Third Servingman',
#  'Young MARCIUS',
#  'First Conspirator',
#  'Second Conspirator',
#  'Third Conspirator',
#  'All The Lords',
#  'Lords',
#  'All Conspirators',
#  'All The People',
#  'Third Lord',
#  'QUEEN',
#  'POSTHUMUS LEONATUS',
#  'IMOGEN',
#  'CYMBELINE',
#  'PISANIO',
#  'CLOTEN',
#  'Lady',
#  'IACHIMO',
#  'PHILARIO',
#  'Frenchman',
#  'First Lady',
#  'CORNELIUS',
#  'CAIUS LUCIUS',
#  'BELARIUS',
#  'GUIDERIUS',
#  'ARVIRAGUS',
#  'First Tribune',
#  'Lord',
#  'First Captain',
#  'Second Captain',
#  'Second Gaoler',
#  'Sicilius Leonatus',
#  'Mother',
#  'First Brother',
#  'Second Brother',
#  'Jupiter',
#  'Posthumus Leonatus',
#  'BERNARDO',
#  'FRANCISCO',
#  'HORATIO',
#  'MARCELLUS',
#  'KING CLAUDIUS',
#  'VOLTIMAND',
#  'LAERTES',
#  'LORD POLONIUS',
#  'HAMLET',
#  'QUEEN GERTRUDE',
#  'OPHELIA',
#  'Ghost',
#  'REYNALDO',
#  'ROSENCRANTZ',
#  'GUILDENSTERN',
#  'First Player',
#  'Prologue',
#  'Player King',
#  'Player Queen',
#  'LUCIANUS',
#  'PRINCE FORTINBRAS',
#  'Danes',
#  'First Sailor',
#  'First Clown',
#  'Second Clown',
#  'First Priest',
#  'OSRIC',
#  'First Ambassador',
#  'Chorus',
#  'CANTERBURY',
#  'ELY',
#  'KING HENRY V',
#  'NYM',
#  'PISTOL',
#  'SCROOP',
#  'CAMBRIDGE',
#  'GREY',
#  'KING OF FRANCE',
#  'DAUPHIN',
#  'Constable',
#  'FLUELLEN',
#  'GOWER',
#  'JAMY',
#  'MACMORRIS',
#  'GOVERNOR',
#  'KATHARINE',
#  'ALICE',
#  'BOURBON',
#  'MONTJOY',
#  'ORLEANS',
#  'RAMBURES',
#  'ERPINGHAM',
#  'COURT',
#  'BATES',
#  'WILLIAMS',
#  'GRANDPRE',
#  'French Soldier',
#  'QUEEN ISABEL',
#  'FRENCH KING',
#  'ABERGAVENNY',
#  'CARDINAL WOLSEY',
#  'First Secretary',
#  'BRANDON',
#  'KING HENRY VIII',
#  'QUEEN KATHARINE',
#  'Surveyor',
#  'SANDS',
#  'LOVELL',
#  'GUILDFORD',
#  'ANNE',
#  'CARDINAL CAMPEIUS',
#  'GARDINER',
#  'Old Lady',
#  'Scribe',
#  'Crier',
#  'GRIFFITH',
#  'LINCOLN',
#  'SURREY',
#  'CROMWELL',
#  'Third Gentleman',
#  'PATIENCE',
#  'CAPUCIUS',
#  'DENNY',
#  'CRANMER',
#  'Keeper',
#  'DOCTOR BUTTS',
#  'Chancellor',
#  'Man',
#  'Garter',
#  'KING JOHN',
#  'CHATILLON',
#  'QUEEN ELINOR',
#  'ESSEX',
#  'BASTARD',
#  'ROBERT',
#  'LADY FAULCONBRIDGE',
#  'GURNEY',
#  'LEWIS',
#  'ARTHUR',
#  'AUSTRIA',
#  'CONSTANCE',
#  'KING PHILIP',
#  'BLANCH',
#  'French Herald',
#  'English Herald',
#  'CARDINAL PANDULPH',
#  'ELINOR',
#  'HUBERT',
#  'First Executioner',
#  'PEMBROKE',
#  'BIGOT',
#  'MELUN',
#  'FLAVIUS',
#  'First Commoner',
#  'MARULLUS',
#  'Second Commoner',
#  'CAESAR',
#  'CASCA',
#  'CALPURNIA',
#  'ANTONY',
#  'CASSIUS',
#  'CICERO',
#  'CINNA',
#  'LUCIUS',
#  'DECIUS BRUTUS',
#  'METELLUS CIMBER',
#  'TREBONIUS',
#  'PORTIA',
#  'LIGARIUS',
#  'PUBLIUS',
#  'ARTEMIDORUS',
#  'POPILIUS',
#  'Several Citizens',
#  'CINNA THE POET',
#  'OCTAVIUS',
#  'LUCILIUS',
#  'PINDARUS',
#  'Poet',
#  'MESSALA',
#  'VARRO',
#  'GHOST',
#  'CLAUDIUS',
#  'TITINIUS',
#  'CATO',
#  'CLITUS',
#  'DARDANIUS',
#  'VOLUMNIUS',
#  'STRATO',
#  'KENT',
#  'EDMUND',
#  'KING LEAR',
#  'GONERIL',
#  'CORDELIA',
#  'LEAR',
#  'REGAN',
#  'CORNWALL',
#  'EDGAR',
#  'OSWALD',
#  'Knight',
#  'Fool',
#  'ALBANY',
#  'CURAN',
#  'Third Servant',
#  'Old Man',
#  'Doctor',
#  'FERDINAND',
#  'LONGAVILLE',
#  'DUMAIN',
#  'BIRON',
#  'DULL',
#  'COSTARD',
#  'ADRIANO DE ARMADO',
#  'MOTH',
#  'ARMADO',
#  'JAQUENETTA',
#  'BOYET',
#  'PRINCESS',
#  'MARIA',
#  'ROSALINE',
#  'SIR NATHANIEL',
#  'HOLOFERNES',
#  'MERCADE',
#  'First Witch',
#  'Second Witch',
#  'Third Witch',
#  'DUNCAN',
#  'MALCOLM',
#  'LENNOX',
#  'ROSS',
#  'MACBETH',
#  'BANQUO',
#  'ANGUS',
#  'LADY MACBETH',
#  'FLEANCE',
#  'MACDUFF',
#  'DONALBAIN',
#  'ATTENDANT',
#  'Both Murderers',
#  'Third Murderer',
#  'HECATE',
#  'First Apparition',
#  'Second Apparition',
#  'Third Apparition',
#  'LADY MACDUFF',
#  'MENTEITH',
#  'CAITHNESS',
#  'SEYTON',
#  'SIWARD',
#  'Soldiers',
#  'YOUNG SIWARD',
#  'DUKE VINCENTIO',
#  'ESCALUS',
#  'LUCIO',
#  'MISTRESS OVERDONE',
#  'CLAUDIO',
#  'Provost',
#  'FRIAR THOMAS',
#  'ISABELLA',
#  'FRANCISCA',
#  'ELBOW',
#  'FROTH',
#  'POMPHEY',
#  'Justice',
#  'JULIET',
#  'ABHORSON',
#  'BARNARDINE',
#  'FRIAR PETER',
#  'ANTONIO',
#  'SALARINO',
#  'SALANIO',
#  'BASSANIO',
#  'LORENZO',
#  'GRATIANO',
#  'NERISSA',
#  'SHYLOCK',
#  'MOROCCO',
#  'LAUNCELOT',
#  'GOBBO',
#  'LEONARDO',
#  'JESSICA',
#  'ARRAGON',
#  'TUBAL',
#  'SALERIO',
#  'BALTHASAR',
#  'STEPHANO',
#  'SHALLOW',
#  'SLENDER',
#  'SIR HUGH EVANS',
#  'PAGE',
#  'SIMPLE',
#  'ANNE PAGE',
#  'Host',
#  'MISTRESS QUICKLY',
#  'RUGBY',
#  'DOCTOR CAIUS',
#  'FENTON',
#  'MISTRESS PAGE',
#  'MISTRESS FORD',
#  'FORD',
#  'ROBIN',
#  'WILLIAM PAGE',
#  'THESEUS',
#  'HIPPOLYTA',
#  'EGEUS',
#  'HERMIA',
#  'LYSANDER',
#  'QUINCE',
#  'BOTTOM',
#  'FLUTE',
#  'STARVELING',
#  'SNOUT',
#  'SNUG',
#  'PUCK',
#  'Fairy',
#  'OBERON',
#  'TITANIA',
#  'PEASEBLOSSOM',
#  'COBWEB',
#  'MUSTARDSEED',
#  'HERNIA',
#  'PHILOSTRATE',
#  'Wall',
#  'Pyramus',
#  'Thisbe',
#  'Lion',
#  'Moonshine',
#  'LEONATO',
#  'BEATRICE',
#  'HERO',
#  'DON PEDRO',
#  'BENEDICK',
#  'DON JOHN',
#  'CONRADE',
#  'BORACHIO',
#  'URSULA',
#  'DOGBERRY',
#  'VERGES',
#  'Watchman',
#  'FRIAR FRANCIS',
#  'Sexton',
#  'RODERIGO',
#  'IAGO',
#  'BRABANTIO',
#  'OTHELLO',
#  'CASSIO',
#  'DUKE OF VENICE',
#  'Sailor',
#  'Senator',
#  'DESDEMONA',
#  'MONTANO',
#  'Fourth Gentleman',
#  'Second Gentlemen',
#  'EMILIA',
#  'First Musician',
#  'BIANCA',
#  'LODOVICO',
#  'ANTIOCHUS',
#  'PERICLES',
#  'Daughter',
#  'THALIARD',
#  'HELICANUS',
#  'CLEON',
#  'DIONYZA',
#  'First Fisherman',
#  'Second Fisherman',
#  'Third Fisherman',
#  'SIMONIDES',
#  'THAISA',
#  'KNIGHTS',
#  'Marshal',
#  'First Knight',
#  'Knights',
#  'ESCANES',
#  'Second Knight',
#  'Third Knight',
#  'LYCHORIDA',
#  'Second Sailor',
#  'CERIMON',
#  'PHILEMON',
#  'LEONINE',
#  'MARINA',
#  'First Pirate',
#  'Second Pirate',
#  'Third Pirate',
#  'Pandar',
#  'BOULT',
#  'Bawd',
#  'LYSIMACHUS',
#  'Tyrian Sailor',
#  'KING RICHARD II',
#  'JOHN OF GAUNT',
#  'HENRY BOLINGBROKE',
#  'THOMAS MOWBRAY',
#  'Lord Marshal',
#  'DUKE OF AUMERLE',
#  'First Herald',
#  'Second Herald',
#  'GREEN',
#  'BUSHY',
#  'DUKE OF YORK',
#  'LORD ROSS',
#  'LORD WILLOUGHBY',
#  'BAGOT',
#  'HENRY PERCY',
#  'LORD BERKELEY',
#  'EARL OF SALISBURY',
#  'BISHOP OF CARLISLE',
#  'SIR STEPHEN SCROOP',
#  'Gardener',
#  'GARDENER',
#  'LORD FITZWATER',
#  'DUKE OF SURREY',
#  'Abbot',
#  'DUCHESS OF YORK',
#  'EXTON',
#  'Groom',
#  'BRAKENBURY',
#  'LADY ANNE',
#  'GENTLEMEN',
#  'DERBY',
#  'DORSET',
#  'CATESBY',
#  'Second murderer',
#  'Girl',
#  'Children',
#  'Lord Mayor',
#  'LORD STANLEY',
#  'Pursuivant',
#  'Priest',
#  'RATCLIFF',
#  'VAUGHAN',
#  'BISHOP OF ELY',
#  'LOVEL',
#  'Scrivener',
#  'ANOTHER',
#  'KING RICHARD III',
#  'TYRREL',
#  'Third Messenger',
#  'Fourth Messenger',
#  'CHRISTOPHER',
#  'RICHMOND',
#  'HERBERT',
#  'BLUNT',
#  'of Prince Edward',
#  'of King Henry VI',
#  'Ghost of CLARENCE',
#  'Ghost of RIVERS',
#  'Ghost of GREY',
#  'Ghost of VAUGHAN',
#  'Ghost of HASTINGS',
#  'of young Princes',
#  'Ghost of LADY ANNE',
#  'of BUCKINGHAM',
#  'LORDS',
#  'SAMPSON',
#  'GREGORY',
#  'ABRAHAM',
#  'BENVOLIO',
#  'TYBALT',
#  'CAPULET',
#  'LADY CAPULET',
#  'LADY MONTAGUE',
#  'ROMEO',
#  'PARIS',
#  'Nurse',
#  'MERCUTIO',
#  'Second Capulet',
#  'FRIAR LAURENCE',
#  'NURSE',
#  'LADY  CAPULET',
#  'Second Musician',
#  'Musician',
#  'Third Musician',
#  'Apothecary',
#  'FRIAR JOHN',
#  'SLY',
#  'First Huntsman',
#  'Second Huntsman',
#  'Players',
#  'A Player',
#  'LUCENTIO',
#  'TRANIO',
#  'BAPTISTA',
#  'GREMIO',
#  'KATHARINA',
#  'HORTENSIO',
#  'HORTENSIA',
#  'BIONDELLO',
#  'PETRUCHIO',
#  'GRUMIO',
#  'KATARINA',
#  'CURTIS',
#  'NATHANIEL',
#  'PHILIP',
#  'JOSEPH',
#  'NICHOLAS',
#  'Pedant',
#  'Haberdasher',
#  'Tailor',
#  'VINCENTIO',
#  'Boatswain',
#  'ALONSO',
#  'GONZALO',
#  'SEBASTIAN',
#  'Mariners',
#  'MIRANDA',
#  'PROSPERO',
#  'ARIEL',
#  'CALIBAN',
#  'ADRIAN',
#  'TRINCULO',
#  'IRIS',
#  'CERES',
#  'JUNO',
#  'Painter',
#  'Merchant',
#  'Jeweller',
#  'TIMON',
#  'Old Athenian',
#  'APEMANTUS',
#  'ALCIBIADES',
#  'Cupid',
#  'All Ladies',
#  'All Lords',
#  'CAPHIS',
#  'All Servants',
#  'FLAMINIUS',
#  'LUCULLUS',
#  'First Stranger',
#  'Second Stranger',
#  'SERVILIUS',
#  'Third Stranger',
#  'SEMPRONIUS',
#  'HORTENSIUS',
#  'PHILOTUS',
#  'Third Senator',
#  'Some Speak',
#  'Some Others',
#  'PHRYNIA',
#  'TIMANDRA',
#  'First Bandit',
#  'Second Bandit',
#  'Third Bandit',
#  'Banditti',
#  'SATURNINUS',
#  'BASSIANUS',
#  'MARCUS ANDRONICUS',
#  'TITUS ANDRONICUS',
#  'TAMORA',
#  'CHIRON',
#  'LAVINIA',
#  'Tribunes',
#  'MUTIUS',
#  'MARTIUS',
#  'QUINTUS',
#  'AARON',
#  'MARCUS',
#  'Young LUCIUS',
#  'AEMILIUS',
#  'First Goth',
#  'All the Goths',
#  'Second Goth',
#  'Third Goth',
#  'TROILUS',
#  'PANDARUS',
#  'AENEAS',
#  'CRESSIDA',
#  'ALEXANDER',
#  'AGAMEMNON',
#  'NESTOR',
#  'ULYSSES',
#  'MENELAUS',
#  'AJAX',
#  'THERSITES',
#  'ACHILLES',
#  'PATROCLUS',
#  'PRIAM',
#  'HECTOR',
#  'HELENUS',
#  'CASSANDRA',
#  'HELEN',
#  'CALCHAS',
#  'DEIPHOBUS',
#  'ANDROMACHE',
#  'MARGARELON',
#  'MYRMIDONS',
#  'DUKE ORSINO',
#  'CURIO',
#  'VALENTINE',
#  'VIOLA',
#  'SIR TOBY BELCH',
#  'SIR ANDREW',
#  'OLIVIA',
#  'MALVOLIO',
#  'FABIAN',
#  'PROTEUS',
#  'SPEED',
#  'JULIA',
#  'LUCETTA',
#  'PANTHINO',
#  'SILVIA',
#  'LAUNCE',
#  'THURIO',
#  'First Outlaw',
#  'Second Outlaw',
#  'Third Outlaw',
#  'EGLAMOUR',
#  'Outlaws',
#  'ARCHIDAMUS',
#  'CAMILLO',
#  'POLIXENES',
#  'LEONTES',
#  'HERMIONE',
#  'MAMILLIUS',
#  'Second Lady',
#  'ANTIGONUS',
#  'PAULINA',
#  'CLEOMENES',
#  'DION',
#  'Mariner',
#  'Time',
#  'AUTOLYCUS',
#  'FLORIZEL',
#  'PERDITA',
#  'DORCAS',
#  'MOPSA',
#  'Shepard']

# %%
players_low = []
for player in players:
    players_low.append(str(player).lower())

# %%
players_low
# Out:
# ['king henry iv',
#  'westmoreland',
#  'falstaff',
#  'prince henry',
#  'poins',
#  'earl of worcester',
#  'northumberland',
#  'hotspur',
#  'sir walter blunt',
#  'first carrier',
#  'ostler',
#  'second carrier',
#  'gadshill',
#  'chamberlain',
#  'bardolph',
#  'peto',
#  'first traveller',
#  'thieves',
#  'travellers',
#  'lady percy',
#  'servant',
#  'francis',
#  'vintner',
#  'hostess',
#  'sheriff',
#  'carrier',
#  'mortimer',
#  'glendower',
#  'nan',
#  'earl of douglas',
#  'messenger',
#  'vernon',
#  'worcester',
#  'archbishop of york',
#  'sir michael',
#  'lancaster',
#  'bedford',
#  'gloucester',
#  'exeter',
#  'of winchester',
#  'charles',
#  'alencon',
#  'reignier',
#  'bastard of orleans',
#  'joan la pucelle',
#  'first warder',
#  'second warder',
#  'woodvile',
#  'mayor',
#  'officer',
#  'boy',
#  'salisbury',
#  'talbot',
#  'gargrave',
#  'glansdale',
#  'sergeant',
#  'first sentinel',
#  'burgundy',
#  'sentinels',
#  'soldier',
#  'captain',
#  'of auvergne',
#  'porter',
#  'plantagenet',
#  'suffolk',
#  'somerset',
#  'warwick',
#  'lawyer',
#  'first gaoler',
#  'king henry vi',
#  'all',
#  'first soldier',
#  'watch',
#  'fastolfe',
#  'basset',
#  'york',
#  'general',
#  'lucy',
#  'john talbot',
#  'legate',
#  'scout',
#  'margaret',
#  'su ffolk',
#  'shepherd',
#  'queen margaret',
#  'cardinal',
#  'buckingham',
#  'duchess',
#  'hume',
#  'first petitioner',
#  'second petitioner',
#  'peter',
#  'horner',
#  'bolingbroke',
#  'spirit',
#  'margaret jourdain',
#  'townsman',
#  'simpcox',
#  'wife',
#  'beadle',
#  'both',
#  'first neighbour',
#  'second neighbour',
#  'third neighbour',
#  'servants',
#  'herald',
#  'stanley',
#  'post',
#  'first murderer',
#  'second murderer',
#  'first murder',
#  'commons',
#  'vaux',
#  'first gentleman',
#  'master',
#  'second gentleman',
#  'whitmore',
#  'bevis',
#  'holland',
#  'cade',
#  'dick',
#  'smith',
#  'clerk',
#  'clerk',
#  'michael',
#  'sir humphrey',
#  'william stafford',
#  'say',
#  'scales',
#  'first citizen',
#  'clifford',
#  'iden',
#  'edward',
#  'richard',
#  'young clifford',
#  'montague',
#  'norfolk',
#  'prince edward',
#  'john mortimer',
#  'rutland',
#  'tutor',
#  'prince',
#  'george',
#  'son',
#  'father',
#  'first keeper',
#  'second keeper',
#  'king edward iv',
#  'clarence',
#  'lady grey',
#  'nobleman',
#  'king lewis xi',
#  'oxford',
#  'bona',
#  'hastings',
#  'queen elizabeth',
#  'first watchman',
#  'second watchman',
#  'third watchman',
#  'rivers',
#  'huntsman',
#  'lieutenant',
#  'all',
#  'first messenger',
#  'second messenger',
#  'countess',
#  'bertram',
#  'lafeu',
#  'helena',
#  'parolles',
#  'page',
#  'king',
#  'first lord',
#  'second lord',
#  'steward',
#  'clown',
#  'both',
#  'fourth lord',
#  'duke',
#  'widow',
#  'diana',
#  'mariana',
#  'second soldier',
#  'gentleman',
#  'orlando',
#  'adam',
#  'oliver',
#  'dennis',
#  'celia',
#  'rosalind',
#  'touchstone',
#  'le beau',
#  'duke frederick',
#  'duke senior',
#  'amiens',
#  'corin',
#  'silvius',
#  'jaques',
#  'audrey',
#  'sir oliver martext',
#  'phebe',
#  'a lord',
#  'forester',
#  'william',
#  'first page',
#  'second page',
#  'hymen',
#  'jaques de boys',
#  'philo',
#  'cleopatra',
#  'mark antony',
#  'attendant',
#  'demetrius',
#  'charmian',
#  'alexas',
#  'soothsayer',
#  'domitius enobarbus',
#  'iras',
#  'first attendant',
#  'second attendant',
#  'octavius caesar',
#  'lepidus',
#  'mardian',
#  'pompey',
#  'menecrates',
#  'menas',
#  'varrius',
#  'mecaenas',
#  'agrippa',
#  'octavia',
#  'attendants',
#  'first servant',
#  'second servant',
#  'ventidius',
#  'silius',
#  'eros',
#  'canidius',
#  'taurus',
#  'scarus',
#  'dolabella',
#  'euphronius',
#  'thyreus',
#  'third soldier',
#  'fourth soldier',
#  'first guard',
#  'second guard',
#  'third guard',
#  'dercetas',
#  'diomedes',
#  'egyptian',
#  'proculeius',
#  'gallus',
#  'seleucus',
#  'guard',
#  'aegeon',
#  'duke solinus',
#  'gaoler',
#  'first merchant',
#  'of syracuse',
#  'dromio of syracuse',
#  'dromio of ephesus',
#  'adriana',
#  'luciana',
#  'of ephesus',
#  'balthazar',
#  'luce',
#  'antipholus',
#  'angelo',
#  'second merchant',
#  'courtezan',
#  'pinch',
#  'aemelia',
#  'second citizen',
#  'menenius',
#  'marcius',
#  'first senator',
#  'cominius',
#  'titus',
#  'sicinius',
#  'brutus',
#  'aufidius',
#  'second senator',
#  'volumnia',
#  'virgilia',
#  'gentlewoman',
#  'valeria',
#  'lartius',
#  'first roman',
#  'second roman',
#  'third roman',
#  'coriolanus',
#  'first officer',
#  'second officer',
#  'senators',
#  'third citizen',
#  'fourth citizen',
#  'fifth citizen',
#  'both citizens',
#  'sixth citizen',
#  'seventh citizen',
#  'all citizens',
#  'citizens',
#  'aedile',
#  'a patrician',
#  'second patrician',
#  'both tribunes',
#  'roman',
#  'volsce',
#  'citizen',
#  'first servingman',
#  'second servingman',
#  'third servingman',
#  'young marcius',
#  'first conspirator',
#  'second conspirator',
#  'third conspirator',
#  'all the lords',
#  'lords',
#  'all conspirators',
#  'all the people',
#  'third lord',
#  'queen',
#  'posthumus leonatus',
#  'imogen',
#  'cymbeline',
#  'pisanio',
#  'cloten',
#  'lady',
#  'iachimo',
#  'philario',
#  'frenchman',
#  'first lady',
#  'cornelius',
#  'caius lucius',
#  'belarius',
#  'guiderius',
#  'arviragus',
#  'first tribune',
#  'lord',
#  'first captain',
#  'second captain',
#  'second gaoler',
#  'sicilius leonatus',
#  'mother',
#  'first brother',
#  'second brother',
#  'jupiter',
#  'posthumus leonatus',
#  'bernardo',
#  'francisco',
#  'horatio',
#  'marcellus',
#  'king claudius',
#  'voltimand',
#  'laertes',
#  'lord polonius',
#  'hamlet',
#  'queen gertrude',
#  'ophelia',
#  'ghost',
#  'reynaldo',
#  'rosencrantz',
#  'guildenstern',
#  'first player',
#  'prologue',
#  'player king',
#  'player queen',
#  'lucianus',
#  'prince fortinbras',
#  'danes',
#  'first sailor',
#  'first clown',
#  'second clown',
#  'first priest',
#  'osric',
#  'first ambassador',
#  'chorus',
#  'canterbury',
#  'ely',
#  'king henry v',
#  'nym',
#  'pistol',
#  'scroop',
#  'cambridge',
#  'grey',
#  'king of france',
#  'dauphin',
#  'constable',
#  'fluellen',
#  'gower',
#  'jamy',
#  'macmorris',
#  'governor',
#  'katharine',
#  'alice',
#  'bourbon',
#  'montjoy',
#  'orleans',
#  'rambures',
#  'erpingham',
#  'court',
#  'bates',
#  'williams',
#  'grandpre',
#  'french soldier',
#  'queen isabel',
#  'french king',
#  'abergavenny',
#  'cardinal wolsey',
#  'first secretary',
#  'brandon',
#  'king henry viii',
#  'queen katharine',
#  'surveyor',
#  'sands',
#  'lovell',
#  'guildford',
#  'anne',
#  'cardinal campeius',
#  'gardiner',
#  'old lady',
#  'scribe',
#  'crier',
#  'griffith',
#  'lincoln',
#  'surrey',
#  'cromwell',
#  'third gentleman',
#  'patience',
#  'capucius',
#  'denny',
#  'cranmer',
#  'keeper',
#  'doctor butts',
#  'chancellor',
#  'man',
#  'garter',
#  'king john',
#  'chatillon',
#  'queen elinor',
#  'essex',
#  'bastard',
#  'robert',
#  'lady faulconbridge',
#  'gurney',
#  'lewis',
#  'arthur',
#  'austria',
#  'constance',
#  'king philip',
#  'blanch',
#  'french herald',
#  'english herald',
#  'cardinal pandulph',
#  'elinor',
#  'hubert',
#  'first executioner',
#  'pembroke',
#  'bigot',
#  'melun',
#  'flavius',
#  'first commoner',
#  'marullus',
#  'second commoner',
#  'caesar',
#  'casca',
#  'calpurnia',
#  'antony',
#  'cassius',
#  'cicero',
#  'cinna',
#  'lucius',
#  'decius brutus',
#  'metellus cimber',
#  'trebonius',
#  'portia',
#  'ligarius',
#  'publius',
#  'artemidorus',
#  'popilius',
#  'several citizens',
#  'cinna the poet',
#  'octavius',
#  'lucilius',
#  'pindarus',
#  'poet',
#  'messala',
#  'varro',
#  'ghost',
#  'claudius',
#  'titinius',
#  'cato',
#  'clitus',
#  'dardanius',
#  'volumnius',
#  'strato',
#  'kent',
#  'edmund',
#  'king lear',
#  'goneril',
#  'cordelia',
#  'lear',
#  'regan',
#  'cornwall',
#  'edgar',
#  'oswald',
#  'knight',
#  'fool',
#  'albany',
#  'curan',
#  'third servant',
#  'old man',
#  'doctor',
#  'ferdinand',
#  'longaville',
#  'dumain',
#  'biron',
#  'dull',
#  'costard',
#  'adriano de armado',
#  'moth',
#  'armado',
#  'jaquenetta',
#  'boyet',
#  'princess',
#  'maria',
#  'rosaline',
#  'sir nathaniel',
#  'holofernes',
#  'mercade',
#  'first witch',
#  'second witch',
#  'third witch',
#  'duncan',
#  'malcolm',
#  'lennox',
#  'ross',
#  'macbeth',
#  'banquo',
#  'angus',
#  'lady macbeth',
#  'fleance',
#  'macduff',
#  'donalbain',
#  'attendant',
#  'both murderers',
#  'third murderer',
#  'hecate',
#  'first apparition',
#  'second apparition',
#  'third apparition',
#  'lady macduff',
#  'menteith',
#  'caithness',
#  'seyton',
#  'siward',
#  'soldiers',
#  'young siward',
#  'duke vincentio',
#  'escalus',
#  'lucio',
#  'mistress overdone',
#  'claudio',
#  'provost',
#  'friar thomas',
#  'isabella',
#  'francisca',
#  'elbow',
#  'froth',
#  'pomphey',
#  'justice',
#  'juliet',
#  'abhorson',
#  'barnardine',
#  'friar peter',
#  'antonio',
#  'salarino',
#  'salanio',
#  'bassanio',
#  'lorenzo',
#  'gratiano',
#  'nerissa',
#  'shylock',
#  'morocco',
#  'launcelot',
#  'gobbo',
#  'leonardo',
#  'jessica',
#  'arragon',
#  'tubal',
#  'salerio',
#  'balthasar',
#  'stephano',
#  'shallow',
#  'slender',
#  'sir hugh evans',
#  'page',
#  'simple',
#  'anne page',
#  'host',
#  'mistress quickly',
#  'rugby',
#  'doctor caius',
#  'fenton',
#  'mistress page',
#  'mistress ford',
#  'ford',
#  'robin',
#  'william page',
#  'theseus',
#  'hippolyta',
#  'egeus',
#  'hermia',
#  'lysander',
#  'quince',
#  'bottom',
#  'flute',
#  'starveling',
#  'snout',
#  'snug',
#  'puck',
#  'fairy',
#  'oberon',
#  'titania',
#  'peaseblossom',
#  'cobweb',
#  'mustardseed',
#  'hernia',
#  'philostrate',
#  'wall',
#  'pyramus',
#  'thisbe',
#  'lion',
#  'moonshine',
#  'leonato',
#  'beatrice',
#  'hero',
#  'don pedro',
#  'benedick',
#  'don john',
#  'conrade',
#  'borachio',
#  'ursula',
#  'dogberry',
#  'verges',
#  'watchman',
#  'friar francis',
#  'sexton',
#  'roderigo',
#  'iago',
#  'brabantio',
#  'othello',
#  'cassio',
#  'duke of venice',
#  'sailor',
#  'senator',
#  'desdemona',
#  'montano',
#  'fourth gentleman',
#  'second gentlemen',
#  'emilia',
#  'first musician',
#  'bianca',
#  'lodovico',
#  'antiochus',
#  'pericles',
#  'daughter',
#  'thaliard',
#  'helicanus',
#  'cleon',
#  'dionyza',
#  'first fisherman',
#  'second fisherman',
#  'third fisherman',
#  'simonides',
#  'thaisa',
#  'knights',
#  'marshal',
#  'first knight',
#  'knights',
#  'escanes',
#  'second knight',
#  'third knight',
#  'lychorida',
#  'second sailor',
#  'cerimon',
#  'philemon',
#  'leonine',
#  'marina',
#  'first pirate',
#  'second pirate',
#  'third pirate',
#  'pandar',
#  'boult',
#  'bawd',
#  'lysimachus',
#  'tyrian sailor',
#  'king richard ii',
#  'john of gaunt',
#  'henry bolingbroke',
#  'thomas mowbray',
#  'lord marshal',
#  'duke of aumerle',
#  'first herald',
#  'second herald',
#  'green',
#  'bushy',
#  'duke of york',
#  'lord ross',
#  'lord willoughby',
#  'bagot',
#  'henry percy',
#  'lord berkeley',
#  'earl of salisbury',
#  'bishop of carlisle',
#  'sir stephen scroop',
#  'gardener',
#  'gardener',
#  'lord fitzwater',
#  'duke of surrey',
#  'abbot',
#  'duchess of york',
#  'exton',
#  'groom',
#  'brakenbury',
#  'lady anne',
#  'gentlemen',
#  'derby',
#  'dorset',
#  'catesby',
#  'second murderer',
#  'girl',
#  'children',
#  'lord mayor',
#  'lord stanley',
#  'pursuivant',
#  'priest',
#  'ratcliff',
#  'vaughan',
#  'bishop of ely',
#  'lovel',
#  'scrivener',
#  'another',
#  'king richard iii',
#  'tyrrel',
#  'third messenger',
#  'fourth messenger',
#  'christopher',
#  'richmond',
#  'herbert',
#  'blunt',
#  'of prince edward',
#  'of king henry vi',
#  'ghost of clarence',
#  'ghost of rivers',
#  'ghost of grey',
#  'ghost of vaughan',
#  'ghost of hastings',
#  'of young princes',
#  'ghost of lady anne',
#  'of buckingham',
#  'lords',
#  'sampson',
#  'gregory',
#  'abraham',
#  'benvolio',
#  'tybalt',
#  'capulet',
#  'lady capulet',
#  'lady montague',
#  'romeo',
#  'paris',
#  'nurse',
#  'mercutio',
#  'second capulet',
#  'friar laurence',
#  'nurse',
#  'lady  capulet',
#  'second musician',
#  'musician',
#  'third musician',
#  'apothecary',
#  'friar john',
#  'sly',
#  'first huntsman',
#  'second huntsman',
#  'players',
#  'a player',
#  'lucentio',
#  'tranio',
#  'baptista',
#  'gremio',
#  'katharina',
#  'hortensio',
#  'hortensia',
#  'biondello',
#  'petruchio',
#  'grumio',
#  'katarina',
#  'curtis',
#  'nathaniel',
#  'philip',
#  'joseph',
#  'nicholas',
#  'pedant',
#  'haberdasher',
#  'tailor',
#  'vincentio',
#  'boatswain',
#  'alonso',
#  'gonzalo',
#  'sebastian',
#  'mariners',
#  'miranda',
#  'prospero',
#  'ariel',
#  'caliban',
#  'adrian',
#  'trinculo',
#  'iris',
#  'ceres',
#  'juno',
#  'painter',
#  'merchant',
#  'jeweller',
#  'timon',
#  'old athenian',
#  'apemantus',
#  'alcibiades',
#  'cupid',
#  'all ladies',
#  'all lords',
#  'caphis',
#  'all servants',
#  'flaminius',
#  'lucullus',
#  'first stranger',
#  'second stranger',
#  'servilius',
#  'third stranger',
#  'sempronius',
#  'hortensius',
#  'philotus',
#  'third senator',
#  'some speak',
#  'some others',
#  'phrynia',
#  'timandra',
#  'first bandit',
#  'second bandit',
#  'third bandit',
#  'banditti',
#  'saturninus',
#  'bassianus',
#  'marcus andronicus',
#  'titus andronicus',
#  'tamora',
#  'chiron',
#  'lavinia',
#  'tribunes',
#  'mutius',
#  'martius',
#  'quintus',
#  'aaron',
#  'marcus',
#  'young lucius',
#  'aemilius',
#  'first goth',
#  'all the goths',
#  'second goth',
#  'third goth',
#  'troilus',
#  'pandarus',
#  'aeneas',
#  'cressida',
#  'alexander',
#  'agamemnon',
#  'nestor',
#  'ulysses',
#  'menelaus',
#  'ajax',
#  'thersites',
#  'achilles',
#  'patroclus',
#  'priam',
#  'hector',
#  'helenus',
#  'cassandra',
#  'helen',
#  'calchas',
#  'deiphobus',
#  'andromache',
#  'margarelon',
#  'myrmidons',
#  'duke orsino',
#  'curio',
#  'valentine',
#  'viola',
#  'sir toby belch',
#  'sir andrew',
#  'olivia',
#  'malvolio',
#  'fabian',
#  'proteus',
#  'speed',
#  'julia',
#  'lucetta',
#  'panthino',
#  'silvia',
#  'launce',
#  'thurio',
#  'first outlaw',
#  'second outlaw',
#  'third outlaw',
#  'eglamour',
#  'outlaws',
#  'archidamus',
#  'camillo',
#  'polixenes',
#  'leontes',
#  'hermione',
#  'mamillius',
#  'second lady',
#  'antigonus',
#  'paulina',
#  'cleomenes',
#  'dion',
#  'mariner',
#  'time',
#  'autolycus',
#  'florizel',
#  'perdita',
#  'dorcas',
#  'mopsa',
#  'shepard']

# %%
split_players = []
for name in players_low:
    for part in name.split(' '):
        split_players.append(part)

# %%
split_players = list(set(split_players))

# %%
split_players
# Out:
# ['',
#  'abbot',
#  'tranio',
#  'peto',
#  'ford',
#  'timandra',
#  'pyramus',
#  'montano',
#  'launce',
#  'sixth',
#  'brakenbury',
#  'murder',
#  'banditti',
#  'belch',
#  'pisanio',
#  'trebonius',
#  'helicanus',
#  'mercutio',
#  'bassianus',
#  'french',
#  'deiphobus',
#  'scales',
#  'westmoreland',
#  'merchant',
#  'juliet',
#  'aeneas',
#  'petruchio',
#  'bardolph',
#  'caliban',
#  'proteus',
#  'troilus',
#  'clerk',
#  'polonius',
#  'menenius',
#  'macmorris',
#  'man',
#  'spirit',
#  'gardener',
#  'talbot',
#  'say',
#  'menelaus',
#  'conrade',
#  'caphis',
#  'pistol',
#  'perdita',
#  'ceres',
#  'philostrate',
#  'tutor',
#  'vi',
#  'forester',
#  'strato',
#  'musician',
#  'macbeth',
#  'bandit',
#  'son',
#  'luciana',
#  'goneril',
#  'others',
#  'lartius',
#  'lion',
#  'cymbeline',
#  'fool',
#  'luce',
#  'arviragus',
#  'percy',
#  'philo',
#  'edward',
#  'aumerle',
#  'hecate',
#  'pandar',
#  'keeper',
#  'cleopatra',
#  'cardinal',
#  'cassius',
#  'publius',
#  'menas',
#  'duncan',
#  'orlando',
#  'mayor',
#  'snout',
#  'oberon',
#  'malcolm',
#  'cleon',
#  'richmond',
#  'viola',
#  'outlaws',
#  'seyton',
#  'enobarbus',
#  'laurence',
#  'norfolk',
#  'marullus',
#  'athenian',
#  'mariner',
#  'princess',
#  'romeo',
#  'poet',
#  'lady',
#  'florizel',
#  'angelo',
#  'diana',
#  'mopsa',
#  'dauphin',
#  'casca',
#  'lords',
#  'hermia',
#  'cade',
#  'moth',
#  'aedile',
#  'balthazar',
#  'antigonus',
#  'michael',
#  'lorenzo',
#  'nurse',
#  'mark',
#  'gardiner',
#  'richard',
#  'gratiano',
#  'servants',
#  'hero',
#  'simpcox',
#  'garter',
#  'pindarus',
#  'bernardo',
#  'roman',
#  'morocco',
#  'alonso',
#  'tamora',
#  'alexas',
#  'canterbury',
#  'cassandra',
#  'gobbo',
#  'tubal',
#  'pinch',
#  'henry',
#  'titus',
#  'of',
#  'lucentio',
#  'cloten',
#  'patience',
#  'basset',
#  'huntsman',
#  'auvergne',
#  'aegeon',
#  'nan',
#  'pedro',
#  'bolingbroke',
#  'second',
#  'paris',
#  'brother',
#  'father',
#  'phrynia',
#  'mutius',
#  'ffolk',
#  'neighbour',
#  'apemantus',
#  'cambridge',
#  'guildenstern',
#  'pomphey',
#  'beadle',
#  'caius',
#  'lucius',
#  'capulet',
#  'bertram',
#  'surveyor',
#  'sempronius',
#  'antony',
#  'volumnius',
#  'jaques',
#  'princes',
#  'fortinbras',
#  'francisca',
#  'master',
#  'leontes',
#  'host',
#  'attendants',
#  'polixenes',
#  'mother',
#  'pandarus',
#  'jourdain',
#  'diomedes',
#  'sicinius',
#  'osric',
#  'katarina',
#  'lepidus',
#  'philemon',
#  'george',
#  'warwick',
#  'ajax',
#  'artemidorus',
#  'holland',
#  'frederick',
#  'jaquenetta',
#  'achilles',
#  'su',
#  'v',
#  'peter',
#  'reynaldo',
#  'simple',
#  'clown',
#  'silius',
#  'dion',
#  'woodvile',
#  'taurus',
#  'starveling',
#  'pucelle',
#  'gremio',
#  'volsce',
#  'audrey',
#  'costard',
#  'outlaw',
#  'oxford',
#  'mecaenas',
#  'marcius',
#  'tribune',
#  'countess',
#  'launcelot',
#  'caesar',
#  'mariana',
#  'gentlewoman',
#  'hortensia',
#  'players',
#  'proculeius',
#  'fitzwater',
#  'murderer',
#  'claudio',
#  'berkeley',
#  'orsino',
#  'officer',
#  'eros',
#  'iden',
#  'pursuivant',
#  'burgundy',
#  'adrian',
#  'bassanio',
#  'plantagenet',
#  'metellus',
#  'boyet',
#  'julia',
#  'bianca',
#  'smith',
#  'helena',
#  'solinus',
#  'pompey',
#  'ventidius',
#  'salanio',
#  'thurio',
#  'old',
#  'haberdasher',
#  'timon',
#  'captain',
#  'alencon',
#  'blanch',
#  'hume',
#  'denny',
#  'chorus',
#  'othello',
#  'bastard',
#  'hamlet',
#  'hugh',
#  'duchess',
#  'clarence',
#  'hernia',
#  'katharina',
#  'lucullus',
#  'brabantio',
#  'tyrrel',
#  'antipholus',
#  'toby',
#  'pedant',
#  'benedick',
#  'silvius',
#  'andronicus',
#  'fifth',
#  'posthumus',
#  'xi',
#  'simonides',
#  'lennox',
#  'crier',
#  'gallus',
#  'macduff',
#  'shallow',
#  'poins',
#  'iras',
#  'dromio',
#  'constance',
#  'townsman',
#  'hermione',
#  'austria',
#  'bishop',
#  'cassio',
#  'jamy',
#  'dennis',
#  'ephesus',
#  'baptista',
#  'lancaster',
#  'tribunes',
#  'attendant',
#  'arthur',
#  'marcellus',
#  'chamberlain',
#  'warder',
#  'wolsey',
#  'ross',
#  'leonardo',
#  'agamemnon',
#  'isabel',
#  'popilius',
#  'king',
#  'carrier',
#  'a',
#  'ghost',
#  'abhorson',
#  'rutland',
#  'watch',
#  'lysander',
#  'alcibiades',
#  'boult',
#  'camillo',
#  'soldiers',
#  'courtezan',
#  'servingman',
#  'girl',
#  'conspirators',
#  'horner',
#  'dionyza',
#  'leonato',
#  'commoner',
#  'all',
#  'english',
#  'moonshine',
#  'pericles',
#  'salarino',
#  'joseph',
#  'de',
#  'wall',
#  'dogberry',
#  'essex',
#  'brutus',
#  'philip',
#  'christopher',
#  'aemelia',
#  'portia',
#  'herbert',
#  'robin',
#  'goth',
#  'griffith',
#  'albany',
#  'helenus',
#  'soldier',
#  'lear',
#  'painter',
#  'cinna',
#  'boatswain',
#  'siward',
#  'servilius',
#  'widow',
#  'slender',
#  'viii',
#  'varro',
#  'thieves',
#  'lincoln',
#  'humphrey',
#  'archbishop',
#  'frenchman',
#  'angus',
#  'green',
#  'page',
#  'olivia',
#  'iachimo',
#  'orleans',
#  'cleomenes',
#  'priest',
#  'laertes',
#  'iv',
#  'tybalt',
#  'adriano',
#  'blunt',
#  'marcus',
#  'nobleman',
#  'maria',
#  'silvia',
#  'steward',
#  'senator',
#  'domitius',
#  'grandpre',
#  'walter',
#  'glansdale',
#  'decius',
#  'ursula',
#  'lafeu',
#  'ambassador',
#  'winchester',
#  'coriolanus',
#  'campeius',
#  'hortensius',
#  'stanley',
#  'dolabella',
#  'bigot',
#  'france',
#  'desdemona',
#  'shepherd',
#  'benvolio',
#  'the',
#  'fluellen',
#  'gertrude',
#  'calchas',
#  'valeria',
#  'sands',
#  'suffolk',
#  'melun',
#  'jessica',
#  'lucy',
#  'several',
#  'antiochus',
#  'ladies',
#  'lucetta',
#  'longaville',
#  'sergeant',
#  'sexton',
#  'daughter',
#  'elizabeth',
#  'octavia',
#  'executioner',
#  'beatrice',
#  'exeter',
#  'fourth',
#  'pirate',
#  'biondello',
#  'cerimon',
#  'peaseblossom',
#  'imogen',
#  'don',
#  'leonatus',
#  'chatillon',
#  'rivers',
#  'volumnia',
#  'evans',
#  'bona',
#  'pembroke',
#  'stephen',
#  'autolycus',
#  'gower',
#  'speak',
#  'menteith',
#  'justice',
#  'hippolyta',
#  'shylock',
#  'celia',
#  'alice',
#  'willoughby',
#  'lovel',
#  'provost',
#  'martius',
#  'egeus',
#  'shepard',
#  'cimber',
#  'isabella',
#  'grey',
#  'lychorida',
#  'cupid',
#  'cato',
#  'curio',
#  'marshal',
#  'thaliard',
#  'montjoy',
#  'dorset',
#  'doctor',
#  'jeweller',
#  'sly',
#  'court',
#  'bates',
#  'guiderius',
#  'overdone',
#  'dull',
#  'ulysses',
#  'servant',
#  'bawd',
#  'scout',
#  'clifford',
#  'lucilius',
#  'gentlemen',
#  'apothecary',
#  'trinculo',
#  'arragon',
#  'falstaff',
#  'paulina',
#  'lucianus',
#  'montague',
#  'egyptian',
#  'phebe',
#  'alexander',
#  'vintner',
#  'grumio',
#  'francis',
#  'elbow',
#  'juno',
#  'euphronius',
#  'escanes',
#  'vaughan',
#  'mamillius',
#  'joan',
#  'touchstone',
#  'sentinel',
#  'flute',
#  'rugby',
#  'capucius',
#  'ratcliff',
#  'virgilia',
#  'hastings',
#  'ostler',
#  'danes',
#  'katharine',
#  'calpurnia',
#  'salerio',
#  'lysimachus',
#  'first',
#  'lieutenant',
#  'stephano',
#  'roderigo',
#  'dick',
#  'fastolfe',
#  'apparition',
#  'quickly',
#  'traveller',
#  'mortimer',
#  'titinius',
#  'cornwall',
#  'witch',
#  'aaron',
#  'catesby',
#  'another',
#  'anne',
#  'andromache',
#  'gurney',
#  'messenger',
#  'robert',
#  'cranmer',
#  'philotus',
#  'chiron',
#  'cicero',
#  'lewis',
#  'boys',
#  'charmian',
#  'erpingham',
#  'friar',
#  'froth',
#  'gaoler',
#  'watchman',
#  'worcester',
#  'puck',
#  'titania',
#  'iii',
#  'abraham',
#  'iris',
#  'kent',
#  'citizens',
#  'scrivener',
#  'tyrian',
#  'dorcas',
#  'travellers',
#  'sicilius',
#  'sheriff',
#  'oliver',
#  'post',
#  'vincentio',
#  'people',
#  'bushy',
#  'seleucus',
#  'northumberland',
#  'commons',
#  'hubert',
#  'flavius',
#  'verges',
#  'salisbury',
#  'claudius',
#  'syracuse',
#  'soothsayer',
#  'bourbon',
#  'theseus',
#  'patrician',
#  'pandulph',
#  'lavinia',
#  'guard',
#  'rosaline',
#  'goths',
#  'queen',
#  'sir',
#  'clitus',
#  'glendower',
#  'legate',
#  'gloucester',
#  'thisbe',
#  'cromwell',
#  'andrew',
#  'marina',
#  'conspirator',
#  'lawyer',
#  'demetrius',
#  'cominius',
#  'myrmidons',
#  'agrippa',
#  'herald',
#  'edmund',
#  'seventh',
#  'ligarius',
#  'fisherman',
#  'aemilius',
#  'prologue',
#  'derby',
#  'surrey',
#  'edgar',
#  'armado',
#  'holofernes',
#  'lucio',
#  'miranda',
#  'margarelon',
#  'corin',
#  'senior',
#  'york',
#  'curan',
#  'antonio',
#  'bottom',
#  'porter',
#  'bedford',
#  'hector',
#  'young',
#  'rambures',
#  'gadshill',
#  'wife',
#  'nicholas',
#  'regan',
#  'elinor',
#  'gargrave',
#  'nestor',
#  'eglamour',
#  'fabian',
#  'earl',
#  'lodovico',
#  'messala',
#  'margaret',
#  'banquo',
#  'groom',
#  'faulconbridge',
#  'petitioner',
#  'gentleman',
#  'player',
#  'mercade',
#  'vaux',
#  'aufidius',
#  'boy',
#  'voltimand',
#  'cobweb',
#  'speed',
#  'fleance',
#  'exton',
#  'mustardseed',
#  'rosencrantz',
#  'patroclus',
#  'varrius',
#  'panthino',
#  'duke',
#  'sentinels',
#  'stranger',
#  'escalus',
#  'malvolio',
#  'mardian',
#  'canidius',
#  'hotspur',
#  'reignier',
#  'john',
#  'curtis',
#  'nathaniel',
#  'martext',
#  'ii',
#  'stafford',
#  'ferdinand',
#  'snug',
#  'sampson',
#  'third',
#  'gonzalo',
#  'archidamus',
#  'lovell',
#  'scarus',
#  'iago',
#  'flaminius',
#  'emilia',
#  'sailor',
#  'oswald',
#  'quintus',
#  'mowbray',
#  'hymen',
#  'vernon',
#  'cressida',
#  'gregory',
#  'ophelia',
#  'thaisa',
#  'mariners',
#  'citizen',
#  'governor',
#  'octavius',
#  'chancellor',
#  'helen',
#  'guildford',
#  'mistress',
#  'charles',
#  'nerissa',
#  'dumain',
#  'butts',
#  'philario',
#  'some',
#  'venice',
#  'douglas',
#  'bevis',
#  'somerset',
#  'murderers',
#  'horatio',
#  'abergavenny',
#  'williams',
#  'barnardine',
#  'balthasar',
#  'gaunt',
#  'menecrates',
#  'fairy',
#  'knight',
#  'tailor',
#  'whitmore',
#  'both',
#  'thersites',
#  'dardanius',
#  'thyreus',
#  'scroop',
#  'la',
#  'fenton',
#  'thomas',
#  'sebastian',
#  'quince',
#  'knights',
#  'dercetas',
#  'valentine',
#  'hostess',
#  'beau',
#  'constable',
#  'scribe',
#  'adriana',
#  'cornelius',
#  'nym',
#  'ariel',
#  'amiens',
#  'jupiter',
#  'senators',
#  'bagot',
#  'donalbain',
#  'hortensio',
#  'parolles',
#  'prince',
#  'le',
#  'general',
#  'lord',
#  'children',
#  'rosalind',
#  'borachio',
#  'time',
#  'leonine',
#  'prospero',
#  'saturninus',
#  'priam',
#  'buckingham',
#  'cordelia',
#  'belarius',
#  'carlisle',
#  'francisco',
#  'caithness',
#  'biron',
#  'william',
#  'secretary',
#  'ely',
#  'adam',
#  'brandon']

# %%
# Save a list of players into a pickle file.
import pickle

pickle.dump( split_players, open( "shake_players.p", "wb" ) )

# %%
#Plays a tone to bring attention to a completed notebook

import os
duration = 1  # second
freq = 440  # Hz
os.system('play --no-show-progress --null --channels 1 synth %s sine %f' % (duration, freq))
